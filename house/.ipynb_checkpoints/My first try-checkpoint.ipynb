# %% [markdown]
# # Heading

# %% [markdown]
# This is some explanatory text.

# %%
import numpy as np
x = 2
print(np.sqrt(x))
# Out:
# 1.41421356237

# %%
np.sqrt(x)
# Out:
# 1.4142135623730951

# %% [markdown]
# another text!
#
# Bla bla.
